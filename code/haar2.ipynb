# %% [markdown]
# # <center> **Haar Filters - Example 2** </center>
# ## <font size=4> **Visión por Computadora 2025** </font> <font color=gray size=4> -- Alan Reyes-Figueroa </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

from skimage.color import rgb2gray, gray2rgb
from skimage import data
from PIL import Image

from time import time 

import cv2

# %% [markdown]
# # Read Image

# %%
imagePath = 'volei.jpeg'

# %%
I = plt.imread(imagePath)
I.shape
# Out:
# (720, 1280, 3)

# %%
plt.figure(figsize=(5,5))
plt.imshow(I)
plt.show()

# %% [markdown]
# # Image (OpenCV)

# %%
img = cv2.imread(imagePath)
img.shape
# Out:
# (720, 1280, 3)

# %%
img = cv2.resize(img, (int(img.shape[1]*1.5), int(img.shape[0]*1.5)))
img.shape
# Out:
# (1080, 1920, 3)

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_image.shape
# Out:
# (1080, 1920)

# %% [markdown]
# # Body Cascade Classifier

# %%
upper_classifier = cv2.CascadeClassifier("haarcascade_upperbody.xml")
lower_classifier = cv2.CascadeClassifier("haarcascade_lowerbody.xml")
body_classifier  = cv2.CascadeClassifier("haarcascade_fullbody.xml")

# %%
upper = upper_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=2, minSize=(20, 10))
lower = lower_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=2, minSize=(20, 10))
body  = body_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=2, minSize=(10, 10))

# %%
upper.shape
# Out:
# (5, 4)

# %%
lower.shape
# Out:
# (5, 4)

# %%
body.shape
# Out:
# (4, 4)

# %%
for (x, y, w, h) in upper:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 128, 255), 3)

# %%
for (x, y, w, h) in lower:
    cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 128), 3)

# %%
for (x, y, w, h) in body:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 128), 3)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 1919.5, 1079.5, -0.5)

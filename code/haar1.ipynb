# %% [markdown]
# # <center> **Haar Filters - Example 1** </center>
# ## <font size=4> **Visión por Computadora 2025** </font> <font color=gray size=4> -- Alan Reyes-Figueroa </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

from skimage.color import rgb2gray, gray2rgb
from skimage import data
from PIL import Image

from time import time 

import cv2

# %% [markdown]
# # Read Image

# %%
imagePath = 'facial-expressions.jpeg'

# %%
I = plt.imread(imagePath)
I.shape
# Out:
# (900, 750, 3)

# %%
plt.figure(figsize=(5,5))
plt.imshow(I)
plt.show()

# %% [markdown]
# # Image (OpenCV)

# %%
img = cv2.imread(imagePath)
img.shape
# Out:
# (900, 750, 3)

# %%
img = cv2.resize(img, (img.shape[1]//2, img.shape[0]//2))
img.shape
# Out:
# (450, 375, 3)

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray_image.shape
# Out:
# (450, 375)

# %% [markdown]
# # Face Cascade Classifier

# %%
face_classifier1  = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#face_classifier2  = cv2.CascadeClassifier("haarcascade_frontalface_alt_tree.xml")
#face_classifier3  = cv2.CascadeClassifier("haarcascade_profileface.xml")

#eyes_classifier  = cv2.CascadeClassifier("haarcascade_eye.xml")
#smile_classifier = cv2.CascadeClassifier("haarcascade_smile.xml")

#upper_classifier = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_upperbody.xml")
#body_classifier  = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_fullbody.xml")

# %%
face1 = face_classifier1.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=1, minSize=(10, 10))



#face2 = face_classifier2.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=1, minSize=(10, 10))
#face3 = face_classifier3.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=1, minSize=(10, 10))

#eyes = eyes_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=20, minSize=(3, 3))
#smil = smile_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=20, minSize=(5, 2))
#uppb = upper_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=10, minSize=(30, 50))
#body = body_classifier.detectMultiScale(gray_image, scaleFactor=1.1, minNeighbors=10, minSize=(30, 100))

# %%
face1.shape
# Out:
# (18, 4)

# %%
face1
# Out:
# array([[317,  30,  36,  36],
#        [168, 137,  34,  34],
#        [318, 144,  36,  36],
#        [170,  26,  37,  37],
#        [ 11,  27,  52,  52],
#        [242,  30,  37,  37],
#        [ 98,  34,  38,  38],
#        [ 11, 141,  48,  48],
#        [241, 151,  49,  49],
#        [162, 369,  34,  34],
#        [315, 362,  39,  39],
#        [239, 363,  39,  39],
#        [ 13, 362,  44,  44],
#        [ 91, 363,  43,  43],
#        [164, 254,  47,  47],
#        [ 92, 250,  41,  41],
#        [232, 248,  60,  60],
#        [307, 244,  63,  63]], dtype=int32)

# %%
for (x, y, w, h) in face1:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

# %%
for (x, y, w, h) in eyes:
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 0, 255), 2)

# %%
for (x, y, w, h) in smil:
    cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,10))
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (-0.5, 374.5, 449.5, -0.5)

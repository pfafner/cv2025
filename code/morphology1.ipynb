# %% [markdown]
# # <center> **Morfología Matemática** </center>
# ## <font size=4> **Visión por Computadora 2025** </font> <font color=gray size=4> -- Alan Reyes-Figueroa </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

import skimage as ski
from skimage.filters import thresholding as th

from skimage import morphology as mo
from scipy import ndimage as ndi

# %% [markdown]
# ## Morphological transformations

# %%
def cross(r=2):
    x = np.zeros((r,r)).astype(int)
    x[:,r//2] = 1
    x[r//2,:] = 1
    x = np.pad(x, [1,1])
    return x

# %%
r = 25
sq = mo.square(r)
st = mo.star(r)
dm = mo.diamond(r)
di = mo.disk(r)
oc = mo.octagon(r, 2)
cr = cross(r)

# %%
plt.figure()
plt.subplot(2,3,1)
plt.imshow(np.pad(sq, [1,1]), cmap='gray')
plt.subplot(2,3,2)
plt.imshow(di, cmap='gray')
plt.subplot(2,3,3)
plt.imshow(st, cmap='gray')
plt.subplot(2,3,4)
plt.imshow(dm, cmap='gray')
plt.subplot(2,3,5)
plt.imshow(oc, cmap='gray')
plt.subplot(2,3,6)
plt.imshow(cr, cmap='gray')
plt.show()

# %% [markdown]
# ## Dilation

# %%
I = plt.imread('circles.png')
I.shape
# Out:
# (256, 256, 4)

# %%
I = ski.color.rgb2gray(I[:,:,:3])
I.shape
# Out:
# (256, 256)

# %%
plt.figure(figsize=(3,3))
plt.imshow(I, cmap='gray')
plt.show()

# %%
se3  = mo.disk(3)
se5  = mo.disk(5)
se7  = mo.disk(7)
se11 = mo.disk(11)

# %%
dilation3  = mo.dilation(I, se3)
dilation5  = mo.dilation(I, se5)
dilation7  = mo.dilation(I, se7)
dilation11 = mo.dilation(I, se11)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(dilation3, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(dilation5, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(dilation7, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(dilation11, cmap='gray')
plt.show()

# %%
se3  = mo.disk(11)
se5  = mo.square(11)
se7  = mo.diamond(11)

# %%
dilation3  = mo.dilation(I, se3)
dilation5  = mo.dilation(I, se5)
dilation7  = mo.dilation(I, se7)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(I, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(dilation3, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(dilation5, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(dilation7, cmap='gray')
plt.show()

# %% [markdown]
# ## Erosion

# %%
I = plt.imread('circles.png')
I.shape
# Out:
# (256, 256, 4)

# %%
I = ski.color.rgb2gray(I[:,:,:3])
I.shape
# Out:
# (256, 256)

# %%
plt.figure(figsize=(4,4))
plt.imshow(I, cmap='gray')
plt.show()

# %%
se3  = mo.disk(3)
se5  = mo.disk(5)
se7  = mo.disk(7)
se11 = mo.disk(11)

# %%
erosion3  = mo.erosion(I, se3)
erosion5  = mo.erosion(I, se5)
erosion7  = mo.erosion(I, se7)
erosion11 = mo.erosion(I, se11)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(erosion3, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(erosion5, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(erosion7, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(erosion11, cmap='gray')
plt.show()

# %% [markdown]
# ## Opening

# %%
I = plt.imread('Cosmos_original.jpeg')
I.shape
# Out:
# (434, 772, 3)

# %%
I = ski.color.rgb2gray(I[:,:,:3])
I.shape
# Out:
# (434, 772)

# %%
I = (255*I).astype(np.uint8)

# %%
I
# Out:
# array([[60, 27, 11, ..., 10, 10, 18],
#        [20, 12,  5, ...,  7,  8,  6],
#        [ 5, 11,  7, ...,  6,  6,  7],
#        ...,
#        [ 1,  5,  7, ...,  6,  5,  9],
#        [ 0,  2,  1, ...,  2,  4, 17],
#        [ 1,  5,  6, ...,  5,  7, 60]], dtype=uint8)

# %%
se05 = mo.disk(5)
se10 = mo.disk(10)
se15 = mo.disk(15)
se20 = mo.disk(20)

# %%
opening05 = mo.opening(I, se05)
opening10 = mo.opening(I, se10)
opening15 = mo.opening(I, se15)
opening20 = mo.opening(I, se20)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(I, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(opening05, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(opening10, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(opening15, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(opening05, cmap='gray')
plt.show()

# %% [markdown]
# ## Closing

# %%
I = plt.imread('Cosmos_original.jpeg')
I.shape
# Out:
# (434, 772, 3)

# %%
I = ski.color.rgb2gray(I[:,:,:3])
I.shape
# Out:
# (434, 772)

# %%
I = (255*I).astype(np.uint8)
I = 255 - I

# %%
plt.figure(figsize=(10,10))
plt.imshow(I, cmap='gray')
plt.show()

# %%
se3  = mo.disk(3)
se5  = mo.disk(5)
se7  = mo.disk(7)
se11 = mo.disk(11)

# %%
closing3  = mo.closing(I, se3)
closing5  = mo.closing(I, se5)
closing7  = mo.closing(I, se7)
closing11 = mo.closing(I, se11)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(I, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(closing3, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(closing5, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(closing7, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(closing5, cmap='gray')
plt.show()

# %% [markdown]
# ## Top-Hat

# %%
I = plt.imread('Cosmos_original.jpeg')
I.shape
# Out:
# (434, 772, 3)

# %%
I = ski.color.rgb2gray(I[:,:,:3])
I.shape
# Out:
# (434, 772)

# %%
I = (255*I).astype(np.uint8)

# %%
se3  = mo.disk(3)
se5  = mo.disk(5)
se7  = mo.disk(7)
se11 = mo.disk(11)

# %%
tophat3  = mo.white_tophat(I, se3)
tophat5  = mo.white_tophat(I, se5)
tophat7  = mo.white_tophat(I, se7)
tophat11 = mo.white_tophat(I, se11)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(I, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(tophat3, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(tophat5, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(tophat7, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(tophat3, cmap='gray')
plt.show()

# %% [markdown]
# ## Black Top-Hat

# %%
I = plt.imread('Cosmos_original.jpeg')
I.shape
# Out:
# (434, 772, 3)

# %%
I = ski.color.rgb2gray(I[:,:,:3])
I.shape
# Out:
# (434, 772)

# %%
I = (255*I).astype(np.uint8)
I = 255 - I

# %%
se3  = mo.disk(3)
se5  = mo.disk(5)
se7  = mo.disk(7)
se11 = mo.disk(11)

# %%
tophat3  = mo.black_tophat(I, se3)
tophat5  = mo.black_tophat(I, se5)
tophat7  = mo.black_tophat(I, se7)
tophat11 = mo.black_tophat(I, se11)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(I, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(tophat3, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(tophat5, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(tophat7, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(tophat5, cmap='gray')
plt.show()

# %% [markdown]
# ## Borders

# %%
I = plt.imread('circles.png')
I.shape
# Out:
# (256, 256, 4)

# %%
I = ski.color.rgb2gray(I[:,:,:3])
I.shape
# Out:
# (256, 256)

# %%
se1 = mo.disk(1)
se3  = mo.disk(3)
se5  = mo.disk(5)
se7  = mo.disk(7)
se11 = mo.disk(11)

# %%
dilation1  = mo.dilation(I, se1)
dilation3  = mo.dilation(I, se3)
dilation5  = mo.dilation(I, se5)
dilation7  = mo.dilation(I, se7)
dilation11 = mo.dilation(I, se11)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(dilation1 - I, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(dilation3 - I, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(dilation5 - I, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(dilation7 - I, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.imshow(dilation1 - I, cmap='gray')
plt.show()

# %%
se1 = mo.disk(1)
se3  = mo.disk(3)
se5  = mo.disk(5)
se7  = mo.disk(7)
se11 = mo.disk(11)

# %%
erosion1  = mo.erosion(I, se1)
erosion3  = mo.erosion(I, se3)
erosion5  = mo.erosion(I, se5)
erosion7  = mo.erosion(I, se7)
erosion11 = mo.erosion(I, se11)

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(I - erosion1, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(I - erosion3, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(I - erosion5, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(I - erosion7, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.imshow(I - erosion1, cmap='gray')
plt.show()

# %%
A = dilation1 - I
B = I - erosion1

# %%
plt.figure(figsize=(6,6))
plt.imshow(A-B, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,4,1)
plt.imshow(dilation1 - erosion1, cmap='gray')
plt.subplot(1,4,2)
plt.imshow(dilation3 - erosion3, cmap='gray')
plt.subplot(1,4,3)
plt.imshow(dilation5 - erosion5, cmap='gray')
plt.subplot(1,4,4)
plt.imshow(dilation7 - erosion7, cmap='gray')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.imshow(dilation1 - erosion1, cmap='gray')
plt.show()

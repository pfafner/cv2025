# %% [markdown]
# # <center> **HOG Descriptor Detection** </center>
# ## <font size=4> **Visión por Computadora 2025** </font> <font color=gray size=4> -- Alan Reyes-Figueroa </font>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns

from skimage.io import imread
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure

from skimage.color import rgb2gray, gray2rgb
from skimage import data
from PIL import Image

from time import time 

import cv2

# %% [markdown]
# # HOG Descriptor for People Detection

# %%
# Load the image and convert it to grayscale
I = cv2.imread('volei.jpeg')
I.shape
# Out:
# (720, 1280, 3)

# %%
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# %%
# Detect people in the image
locations, confidence = hog.detectMultiScale(I)

# %%
# Draw rectangles around the detected people
for (x, y, w, h) in locations:
    cv2.rectangle(I, (x, y), (x + w, y + h), (0, 0, 255), 5)

# %%
print(locations)
# Out:
# [[1012   70   91  182]
#  [ 512  354  104  209]
#  [ 217  372  105  211]
#  [ 398  386  103  206]
#  [ 841  386  123  246]
#  [1155  523   92  183]
#  [ 556  496  107  215]
#  [ 985  297   81  161]
#  [ 703  301   75  150]
#  [ 239  191   81  162]
#  [ 426   30  142  283]
#  [ 853  465   65  130]]

# %%
confidence
# Out:
# array([1.06280321, 1.58065465, 1.61176323, 1.75548438, 0.89286511,
#        2.91582004, 2.24116596, 0.58827325, 1.58990333, 0.49936141,
#        0.63158643, 0.51295197])

# %%
I_rgb = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,10))
plt.imshow(I_rgb)
#plt.axis('off')
